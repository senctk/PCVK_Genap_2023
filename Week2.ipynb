# %% [markdown]
# <a href="https://colab.research.google.com/github/nesaitfirullail/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_Genap/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_Genap/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
plt.imshow(img_gray, cmap='RdBu')

# %%
plt.imshow(img_gray, cmap='PRGn')

# %%
blck_img = np.zeros(shape=(512,512,3),dtype=np.int16)

cv.rectangle(blck_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
cv.rectangle(blck_img,pt1=(100,100),pt2=(200,200),color=(0,255,0),thickness=15)
cv.rectangle(blck_img,pt1=(300,300),pt2=(400,400),color=(255,0,0),thickness=15)
cv.rectangle(blck_img,pt1=(500,500),pt2=(400,400),color=(255,255,255),thickness=15)
cv.rectangle(blck_img,pt1=(50,50),pt2=(100,100),color=(255,0,255),thickness=15)
plt.imshow(blck_img)

# %%
img_nesa = cv.imread('/content/drive/MyDrive/PCVK_Genap/Images/nesa.jpg')
img_nesa2 = cv.cvtColor(img_nesa, cv.COLOR_BGR2RGB)

cv.rectangle(img_nesa2,pt1=(200,800),pt2=(600,400),color=(255,0,0),thickness=10)
cv.circle(img_nesa2,center=(400,600),radius=250,color=(255,0,0),thickness=8)
plt.imshow(img_nesa2)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_Genap/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
cv.rectangle(img_gray,pt1=(150,175),pt2=(0,215),color=(0,0,255),thickness=2)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img_gray,text='Kitten',org=(25,200),fontFace=font,fontScale=1,color=(255,255,255),thickness=3,lineType=cv.LINE_AA)
plt.imshow(img_gray)
